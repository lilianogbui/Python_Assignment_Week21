# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.3.2-cp313-cp313-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.0 MB 333.1 kB/s eta 0:00:31
# ...

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.2

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %% [markdown]
# import pandas as pd

# %%
import pandas as pd

# %% [raw]
# pd.read_csv(r"C:\Users\USER\Documents\csv files\Department Workforce.csv")

# %%
df = pd.read_csv(r"C:\Users\USER\Documents\csv files\Department Workforce.csv")
df
# Out:
#                   department  total_hired  active_employees  terminations
# 0                Engineering         6686              5846           840
# 1                 Accounting         3333              2929           404
# 2                      Sales         1832              1603           229
# 3            Human Resources         1807              1582           225
# 4                   Training         1692              1475           217
# 5                   Services         1686              1482           204
# 6       Business Development         1642              1461           181
# 7   Research and Development         1084               949           135
# 8                    Support          954               834           120
# 9         Product Management          641               566            75
# 10                 Marketing          494               441            53
# 11                     Legal          311               264            47
# ...
